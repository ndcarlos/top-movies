# %% [markdown]
# # Top Rated Movies

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# %%
# install chunk

# %%
dat = pd.read_csv('/Users/noahcarlos/Documents/Projects/Python/Top Rated Movie 10.24/movie.csv')
dat
# Out:
#       Unnamed: 0      id                title  \
# 0              0  960258           Shark Bait
# 1              1   11067      Major League II
# 2              2   20856  Aliens in the Attic
# 3              3   14098             100 Feet
# 4              4   11398       The Art of War
# ...          ...     ...                  ...
# 8575        8575   10723          Bulletproof
# 8576        8576  397422          Rough Night
# 8577        8577   70435              Haywire
# 8578        8578   36599           Prom Night
# 8579        8579   23410             The Thaw
#
#                                                overview release_date  \
# 0     A group of friends enjoying a weekend steal a ...   2022-05-13
# 1     After losing in the ALCS the year before, the ...   1994-03-30
# 2     A group of kids must protect their vacation ho...   2009-07-30
# 3     After Marnie Watson kills her abusive husband ...   2008-07-22
# 4     Neil Shaw is both agent and weapon - a critica...   2000-08-25
# ...                                                 ...          ...
# 8575  An undercover police officer named Rock Keats ...   1996-09-06
# 8576  Five best friends from college reunite 10 year...   2017-06-15
# 8577  A black ops soldier seeks payback after she is...   2011-11-01
# 8578  At a high school senior prom, a masked killer ...   1980-07-18
# 8579  At a remote Arctic research station, four ecol...   2009-08-30
#
#       popularity  vote_average  vote_count
# 0         34.679         5.697         318
# 1         16.374         5.697         320
# 2         20.437         5.696         973
# 3         18.927         5.696         304
# 4         12.022         5.696         477
# ...          ...           ...         ...
# 8575      12.428         5.700         569
# 8576      19.368         5.688        1963
# 8577      17.259         5.700        1333
# 8578      15.854         5.700         414
# 8579      18.424         5.689         304
#
# [8580 rows x 8 columns]

# %%
print(dat.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8580 entries, 0 to 8579
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8580 non-null   int64
#  1   id            8580 non-null   int64
#  2   title         8580 non-null   object
#  3   overview      8579 non-null   object
#  4   release_date  8580 non-null   object
#  5   popularity    8580 non-null   float64
#  6   vote_average  8580 non-null   float64
#  7   vote_count    8580 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 536.4+ KB
# None

# %%
dat.describe()
# Out:
#         Unnamed: 0            id   popularity  vote_average    vote_count
# count  8580.000000  8.580000e+03  8580.000000   8580.000000   8580.000000
# mean   4289.500000  1.964095e+05    29.863904      6.804031   2104.044172
# std    2476.976988  2.608837e+05    53.930147      0.628188   3264.360149
# min       0.000000  2.000000e+00     0.023000      5.688000    300.000000
# 25%    2144.750000  9.922750e+03    14.722750      6.300000    477.000000
# 50%    4289.500000  3.461200e+04    20.945500      6.769000    895.000000
# 75%    6434.250000  3.636032e+05    32.027750      7.272000   2137.500000
# max    8579.000000  1.212073e+06  3011.577000      8.706000  36238.000000

# %% [markdown]
# ###### not sure about the histogram below. need a better understanding of how popularity is calculated

# %%
# Popularity Histogram

pop_filter = dat[(dat['popularity'] >= 0) & (dat['popularity'] <= 200)]
sns.histplot(pop_filter['popularity'], bins = 50)
plt.title("Count of Movies by Popularity")
plt.xlabel('Popularity')
plt.ylabel('Count')
plt.show()

# %%
# movie count by average rating

sns.histplot(dat, x = 'vote_average', bins = 10)
plt.title('Count of Movies by Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Count')
plt.show()

# %%
# Movie count by vote count

sns.histplot(dat, x = 'vote_count', bins = 5)
plt.title("Movie Count by Vote Count")
plt.xlabel('Vote Count')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# Considering the statistical details about **vote_count** printed earlier using the <code>.describe()</code> function along with the histogram above, it becomes evident that the data is very much right skewed.

# %%
# check skewness metric
dat['vote_count'].skew()
# Out:
# 3.830061623228037

# %% [markdown]
# In order to try and improve the readability of this plot, I am going to invoke the central limit theorem to reduce the size of the dataset. The reason for this is to help eliminate the extremely high valued outliers which severely compromise the quality of the visualization.

# %%
# set up new upper and lower bounds

mean_vc = np.mean(dat['vote_count'])
sd_vc = np.std(dat['vote_count'])

# setting lower bound to 0 because it is calculated to be negative due to skewedness
lowerbound_vc = 0

# upper bound
upperbound_vc = mean_vc + 2 * sd_vc

# updated data frame for plot
plotdata_vc = dat[(dat['vote_count'] >= lowerbound_vc) & (dat['vote_count'] <= upperbound_vc)]

plotdata_vc
# Out:
#       Unnamed: 0      id                title  \
# 0              0  960258           Shark Bait
# 1              1   11067      Major League II
# 2              2   20856  Aliens in the Attic
# 3              3   14098             100 Feet
# 4              4   11398       The Art of War
# ...          ...     ...                  ...
# 8575        8575   10723          Bulletproof
# 8576        8576  397422          Rough Night
# 8577        8577   70435              Haywire
# 8578        8578   36599           Prom Night
# 8579        8579   23410             The Thaw
#
#                                                overview release_date  \
# 0     A group of friends enjoying a weekend steal a ...   2022-05-13
# 1     After losing in the ALCS the year before, the ...   1994-03-30
# 2     A group of kids must protect their vacation ho...   2009-07-30
# 3     After Marnie Watson kills her abusive husband ...   2008-07-22
# 4     Neil Shaw is both agent and weapon - a critica...   2000-08-25
# ...                                                 ...          ...
# 8575  An undercover police officer named Rock Keats ...   1996-09-06
# 8576  Five best friends from college reunite 10 year...   2017-06-15
# 8577  A black ops soldier seeks payback after she is...   2011-11-01
# 8578  At a high school senior prom, a masked killer ...   1980-07-18
# 8579  At a remote Arctic research station, four ecol...   2009-08-30
#
#       popularity  vote_average  vote_count
# 0         34.679         5.697         318
# 1         16.374         5.697         320
# 2         20.437         5.696         973
# 3         18.927         5.696         304
# 4         12.022         5.696         477
# ...          ...           ...         ...
# 8575      12.428         5.700         569
# 8576      19.368         5.688        1963
# 8577      17.259         5.700        1333
# 8578      15.854         5.700         414
# 8579      18.424         5.689         304
#
# [8183 rows x 8 columns]

# %% [markdown]
# Creating an improved histogram

# %%
sns.histplot(plotdata_vc['vote_count'], bins =10, kde = True)
plt.show()

# %% [markdown]
# What are the movies that received so many votes?

# %%
# top 150 vote recievers 

dat_150vc = dat.sort_values(by = 'vote_count', ascending = False).head(150)
dat_150vc
# Out:
#       Unnamed: 0      id                                      title  \
# 68            68   27205                                  Inception
# 41            41  157336                               Interstellar
# 27            27     155                            The Dark Knight
# 1062        1062   19995                                     Avatar
# 962          962  293660                                   Deadpool
# ...          ...     ...                                        ...
# 2199        2199     285   Pirates of the Caribbean: At World's End
# 2202        2202     285   Pirates of the Caribbean: At World's End
# 195          195     500                             Reservoir Dogs
# 503          503  152601                                        Her
# 1953        1953  122917  The Hobbit: The Battle of the Five Armies
#
#                                                overview release_date  \
# 68    Cobb, a skilled thief who commits corporate es...   2010-07-15
# 41    The adventures of a group of explorers who mak...   2014-11-05
# 27    Batman raises the stakes in his war on crime. ...   2008-07-16
# 1062  In the 22nd century, a paraplegic Marine is di...   2009-12-15
# 962   The origin story of former Special Forces oper...   2016-02-09
# ...                                                 ...          ...
# 2199  Will Turner and Elizabeth Swann join forces wi...   2007-05-19
# 2202  Will Turner and Elizabeth Swann join forces wi...   2007-05-19
# 195   A botched robbery indicates a police informant...   1992-09-02
# 503   In the not so distant future, Theodore, a lone...   2013-12-18
# 1953  Immediately after the events of The Desolation...   2014-12-10
#
#       popularity  vote_average  vote_count
# 68        94.760         8.368       36238
# 41       177.797         8.440       35110
# 27       166.733         8.516       32494
# 1062      99.465         7.583       31233
# 962      185.118         7.621       30672
# ...          ...           ...         ...
# 2199     102.676         7.258       14117
# 2202     102.676         7.258       14116
# 195       44.820         8.126       14103
# 503       62.629         7.857       14078
# 1953     143.051         7.323       14065
#
# [150 rows x 8 columns]

# %%
# ratings Histogram

mu, std = norm.fit(dat['vote_average'])

plt.hist(dat['vote_average'], bins = 10, density = True)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.title('Distribution of Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Probability')

plt.plot(x, p, 'k', linewidth = 2)

# %% [markdown]
# ##### no bins! maybe something to mention in analysis

# %% [markdown]
# ### Most popular _____

# %%
# 10 most popular movies


mp_movies = dat.sort_values(by = 'vote_average', ascending = False)

mp_movies.head(10)
# Out:
#     Unnamed: 0      id                        title  \
# 20          20     278     The Shawshank Redemption
# 21          21     238                The Godfather
# 22          22     240        The Godfather Part II
# 23          23     424             Schindler's List
# 24          24     389                 12 Angry Men
# 25          25     129                Spirited Away
# 26          26   19404  Dilwale Dulhania Le Jayenge
# 27          27     155              The Dark Knight
# 28          28  496243                     Parasite
# 29          29     497               The Green Mile
#
#                                              overview release_date  \
# 20  Imprisoned in the 1940s for the double murder ...   1994-09-23
# 21  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 22  In the continuing saga of the Corleone crime f...   1974-12-20
# 23  The true story of how businessman Oskar Schind...   1993-12-15
# 24  The defense and the prosecution have rested an...   1957-04-10
# 25  A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 26  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 27  Batman raises the stakes in his war on crime. ...   2008-07-16
# 28  All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 29  A supernatural tale set on death row in a Sout...   1999-12-10
#
#     popularity  vote_average  vote_count
# 20     191.303         8.706       26757
# 21     152.632         8.690       20306
# 22      90.368         8.574       12244
# 23      92.258         8.565       15659
# 24      70.095         8.544        8490
# 25     139.663         8.535       16288
# 26      53.491         8.531        4422
# 27     166.733         8.516       32494
# 28     103.416         8.507       17981
# 29      97.284         8.507       17182

# %%
# bar graph of annual popularity

mp_movies['release_year'] = pd.to_datetime(mp_movies['release_date']).dt.year



sns.histplot(mp_movies['release_year'].head(200), bins = 10, stat = 'percent')
plt.title('Percent of Most Popular Movies by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Percent')
plt.show()

# %%
# genres v popularity

sns.countplot(mp_movies['genre'].head(200))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 3
#       1 # genres v popularity
# ----> 3 sns.countplot(mp_movies['genre'].head(200))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'genre'

# %%
for col in dat:
    sns.histplot(x=col, data = dat, kde=True)
    plt.show()
